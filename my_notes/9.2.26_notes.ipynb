# %% [markdown]
# 9.2.26 Lab: Dive into the uhashring repo

# %%
from uhashring import HashRing

# create a consistent hash ring of 3 nodes of weight 1
hr = HashRing(nodes=['node1', 'node2', 'node3'])

# get the node name for the 'coconut' key
target_node = hr.get_node('coconut')

print(target_node)
# Out:
# node2

# %%
# get the 'coconut' key from the right host's redis instance
hr.get('coconut')
# Out:
# {'hostname': 'node2',
#  'instance': None,
#  'nodename': 'node2',
#  'port': None,
#  'vnodes': 160,
#  'weight': 1}

# %% [markdown]
# Where is the hash created? (in the ring.py file)

# %%
hr.get_node('coconut')
# Out:
# 'node2'

# %%
hr.get_server('coconut')
# Out:
# (157285054189446768912416291781797853523, 'node2')

# %% [markdown]
# How many virtual nodes are created for each physical node?

# %%
hr.get('coconut')
# Out:
# {'hostname': 'node2',
#  'instance': None,
#  'nodename': 'node2',
#  'port': None,
#  'vnodes': 160,
#  'weight': 1}

# %% [markdown]
# 160 (see ring.py line 30)

# %% [markdown]
# Where are virtual nodes created?

# %% [markdown]
# What is the naming convention for virtual nodes?

# %%
hr.get_nodes()
# Out:
# dict_keys(['node1', 'node2', 'node3'])

# %% [markdown]
# Return all the ring positions for node 1.

# %%
hr.get_node_pos('node2')
# Out:
# 216

# %% [markdown]
# Revisit the example from Basic usage and look at the target_n for the key 'coconut'.
